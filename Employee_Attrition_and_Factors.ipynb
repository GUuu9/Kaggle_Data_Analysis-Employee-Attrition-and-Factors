# %% [markdown]
# #### https://www.kaggle.com/datasets/thedevastator/employee-attrition-and-factors

# %% [markdown]
# # Employee Attrition and Factors
# sub - Examining Performance, Financials, and Job Role for Impact on Retention
# ## 직원 감소 및 요인에 관한 분석
# 부제 - 보존에 미치는 영향에 대한 성과, 재정 및 직무 역할 조사

# %% [markdown]
# ## About this dataset
# This dataset offers a comprehensive and varied analysis of an organization's employees, focusing on areas such as employee attrition, personal and job-related factors, and financials. Included are numerous parameters such as Age, Gender, Marital Status, Business Travel Frequency, Daily Rate of Pay, Departmental Information such as Distance From Home Office or Education Level Obtained by the employee in question. Also included is a variant series of parameters related to the job being performed such as Job Involvement (level), Job Level (relative to similar roles within the same organization), Job Role specifically meant for that individual(function/task), total working hours in a week/month/year be it overtime or standard hours for a given role. Furthermore detailed aspects include Percent Salary Hike during their tenure with the company from promotion or otherwise , Performance Rating based on specific criteria established by leadership , Relationship Satisfaction among peers at workplace but also taking into account outside family members that can influence stress levels in varying capacities ,Monthly Income considered at its starting point once hired then compared against their monthly payrate with overtime hours included if applicable along with Number Companies Worked before if any. Lastly the Retirement Status commonly known as Attrition is highlighted; covering whether there was an intent to stay with one employer through retirement age or if attrition took place for reasons beyond ones control earlier than expected . Through this dataset you can get an insight into various major aspect regarding today's workforce management philosphies which have changed drastically over time due to advancements in technology
#
# 이 데이터 세트는 직원 감소, 개인 및 직무 관련 요인, 재무와 같은 영역에 초점을 맞춘 조직의 직원에 대한 포괄적이고 다양한 분석을 제공합니다. 여기에는 나이, 성별, 결혼 여부, 출장 빈도, 일급 비율, 해당 직원이 획득한 집과의 거리 또는 교육 수준과 같은 부서 정보와 같은 수많은 매개 변수가 포함됩니다. 또한 수행 중인 작업과 관련된 일련의 매개 변수가 포함됩니다. 예를 들어, 작업 참여(수준), 작업 수준(동일한 조직 내에서 유사한 역할에 상대적), 해당 개인을 위해 특별히 의미된 작업 역할(기능/작업), 주/월/년의 총 작업 시간(초과 또는 특정 역할의 표준 시간). 더 자세한 측면은 승진 또는 그렇지 않은 경우 회사에 재직하는 동안의 퍼센트 급여 인상, 리더십에 의해 확립된 특정 기준에 기초한 성과 평가, 직장 동료들 간의 관계 만족도를 고려하지만 다양한 능력에서 스트레스 수준에 영향을 미칠 수 있는 외부 가족 구성원을 고려하는 것을 포함한다월 소득은 일단 고용되면 그 시작점에서 고려되며, 적용 가능한 경우 이전에 근무한 번호 회사와 함께 초과 근무 시간이 포함된 월 급여율과 비교됩니다. 마지막으로 일반적으로 '퇴거 상태'로 알려진 '퇴거 상태'가 강조됩니다. 즉, 정년까지 한 고용주에 머물 의향이 있었는지 또는 예상보다 일찍 통제할 수 없는 이유로 감소가 발생했는지 여부를 포함합니다. 이 데이터 세트를 통해 기술의 발전으로 인해 시간이 지남에 따라 급격하게 변화한 오늘날의 인력 관리 철학에 대한 다양한 주요 측면을 통찰할 수 있습니다

# %%
# Call data
import pandas as pd
data_use = pd.read_csv('./HR_Analytics.csv')

# %%
data_use.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# 모든 컬럼 보기
pd.set_option('display.max_columns', 35)
data_use.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# ## 컬럼 정보
#
# |Column name|Description|컬럼의 의미|
# |-----------|-----------|---------|
# |Age|The age of the employee. (Numerical)|직원의 나이|
# |Attrition|Whether or not the employee has left the organization. (Categorical)|퇴사 여부|
# |BusinessTravel|The frequency of business travel for the employee. (Categorical)|출장 빈도|
# |DailyRate|The daily rate of pay for the employee. (Numerical)|일별 급여|
# |Department|The department the employee works in. (Categorical)|부서|
# |DistanceFromHome|The distance from home in miles for the employee. (Numerical)|집과의 거리|
# |Education|The level of education achieved by the employee. (Categorical)|교육 수준|
# |EducationField|The field of study for the employee's education. (Categorical)|교육 분야|
# |EmployeeCount|The total number of employees in the organization. (Numerical)|조직의 인원수|
# |EmployeeNumber|A unique identifier for each employee profile. (Numerical)|직원 번호|
# |EnvironmentSatisfaction|The employee's satisfaction with their work environment. (Categorical)|근무환경만족도|
# |Gender|The gender of the employee. (Categorical)|성별|
# |HourlyRate|The hourly rate of pay for the employee. (Numerical)|시급|
# |JobInvolvement|The level of involvement required for the employee's job. (Categorical)|작업 참여|
# |JobLevel|The job level of the employee. (Categorical)|업무 강도|
# |JobRole|The role of the employee in the organization. (Categorical)|담당 업무|
# |JobSatisfaction|The employee's satisfaction with their job. (Categorical)|직업 만족도|
# |MaritalStatus|The marital status of the employee. (Categorical)|결혼 여부|
# |MonthlyIncome|The monthly income of the employee. (Numerical)|월 수입|
# |MonthlyRate|The monthly rate of pay for the employee. (Numerical)|직원 월 급여율?|
# |NumCompaniesWorked|The number of companies the employee has worked for. (Numerical)|이직 횟수|
# |Over18|Whether or not the employee is over 18. (Categorical)|18세 이상|
# |OverTime|Whether or not the employee works overtime. (Categorical)|초과근무여부|
# |PercentSalaryHike|The percentage of salary hike for the employee. (Numerical)|급여 인상 비율|
# |PerformanceRating|The performance rating of the employee. (Categorical)|직원 성과 등급|
# |RelationshipSatisfaction|The employee's satisfaction with their relationships. (Categorical)|직원들과의 관계 만족도|
# |StandardHours|The standard hours of work for the employee. (Numerical)|표준 근무 시간|
# |StockOptionLevel|The stock option level of the employee. (Numerical)|스톡옵션 수준|
# |TotalWorkingYears|The total number of years the employee has worked. (Numerical)|총 근무 년도|
# |TrainingTimesLastYear|The number of times the employee was taken for training in the last year. (Numerical)|작년 교육받은 횟수|
# |WorkLifeBalance|The employee's perception of their work-life balance. (Categorical)|일과 일상의 균형|
# |YearsAtCompany|The number of years the employee has been with the company. (Numerical)|근속년수|
# |YearsInCurrentRole|The number of years the employee has been in their current role. (Numerical)|해당 업무를 담당한 기간(년)|
# |YearsSinceLastPromotion|The number of years since the employee's last promotion. (Numerical)|마지막으로 승진하고 지난 기간(년)|
# |YearsWithCurrManager|The number of years the employee has been with their current manager. (Numerical)|현재 관리자와 함께 근무한 기간|

# %%
data_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ### 모든 컬럼의 데이터가 1470개로 결측치는 없는 것으로 판단.

# %% [markdown]
# # 분석
# ## 분석 방향
# - 남성과 여성 직원을 구분하여 각 연령대 별로 퇴사 여부를 확인해 근무중인 인원과 퇴사한 인원의 정보를 확인한다.
# - 위의 정보를 토대로 직원이 감소하는 이유와, 퇴사할 가능성이 있는 직원을 찾아보도록 한다.
#
# ## 분석 진행
# 1. 데이터를 확인하여 불필요하다 판단되는 컬럼을 제거한다.(ex:모두 동일한 값)
# 2. 남성과 여성 직원을 분류하여 데이터 프레임을 생성한다.

# %% [markdown]
# ### 각 컬럼의 데이터 살펴보기

# %%
data_use
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ### 시각화를 통해 불필요하다 판단되는 컬럼을 제거 하였습니다.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_use.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
col_list = ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
       'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']

for i in col_list:
    plt.figure(figsize=(20,8))
    sns.countplot(x=data_use[i])
# Out:
# /var/folders/y5/nqpm4kl92mq8lmqkqs0vypc40000gn/T/ipykernel_4563/185504171.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(20,8))

# %% [markdown]
# |컬럼 명|제외 이유|
# |-----|-------|
# |EmployeeCount|모든 데이터가 1명의 근무자로 처리되어 있다.|
# |EmployeeNumber|개개인의 직원 번호이므로 퇴사 사유에 부적합 하다고 판단|
# |Over18|모든 직원들이 18세 이상의 성인들로 구성되어 있다.|
# |StandardHours|표즌 근무시간이 모두 80으로 설정되어 있다.|

# %%
data_use = data_use.drop(columns=["EmployeeCount", "EmployeeNumber", "Over18", "StandardHours"], axis=1)
data_use
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %% [markdown]
# #### 삭제이후 35개의 컬럼에서 -> 31개의 컬럼으로 줄어들었습니다.

# %% [markdown]
# ### 남성 직원과 여성 직원을 나누어 비교하였습니다.

# %%
data_Male = data_use[data_use["Gender"] == 'Male']
data_Female = data_use[data_use["Gender"] == 'Female']

# %%
data_Male
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %% [markdown]
# ### df.unique() 함수를 통해 컬럼의 값들이 분리되었는지 확인합니다.

# %%
data_Male["Gender"].unique()
# Out:
# array(['Male'], dtype=object)

# %%
data_Female["Gender"].unique()
# Out:
# array(['Female'], dtype=object)

# %% [markdown]
# ## data_Male
# ### 남성 직원이 퇴사하는 이유를 찾아봅니다.

# %%
data_Male.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# 퇴사 여부 확인을 위한 Attrition을 제외하고 시각화를 하여 살펴봅니다.

# %%
data_M_list=['Age', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField',
       'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
       'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
       'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
       'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
       'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
       'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager']
for i in data_M_list:
    plt.figure(figsize=(20,8))
    sns.countplot(data=data_Male, x=i, hue="Attrition")
# Out:
# /var/folders/y5/nqpm4kl92mq8lmqkqs0vypc40000gn/T/ipykernel_4563/3666011824.py:11: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(20,8))
